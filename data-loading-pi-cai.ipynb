# %% [markdown]
# # Data operations for PI-CAI operations
#
# *José Guilherme de Almeida*
#
# Here I develop data operations that retrieve data from the PI-CAI dataset. The outcome is a MONAI data generator that yields 1) the MRI data, 2) the segmentation mask, 3) the biological data/labels associated each scan.

# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm,trange
from glob import glob
from lib.dataoperations.lib.data_functions import *

# %% [markdown]
# ## Implementing a CSV dataset and labels class

# %%
clinical_info_path = "/home/jose_almeida/data/PI-CAI/labels/clinical_information/marksheet.csv"

def retrieve_clinical_data(path:str)->dict:
    with open(path) as o:
        lines = [x.strip() for x in o.readlines()]

    header = lines[0].split(',')
    data_dict = {k:[] for k in header}
    for line in lines[1:]:
        cur_word = ''
        comma_count = 0
        quotes = 0
        for char in line:
            if char == '"':
                quotes = 1-quotes
            elif char == ',' and quotes == 0:
                data_dict[header[comma_count]].append(cur_word)
                comma_count += 1
                cur_word = ''
            elif char == ',' and quotes == 1:
                cur_word += char
            else:
                cur_word += char
        data_dict[header[comma_count]].append(cur_word)

    relevant_fields = [
        'study_id','patient_age','psa',
        'prostate_volume','histopath_type','lesion_GS']
    dataset_dict = {}
    for s,a,p,v,c,l in zip(*[data_dict[k] for k in relevant_fields]):
        l_out = 0
        for ll in l.split(','):
            ll = ll.strip()
            if ll != "N/A" and ll != "":
                tmp = sum([int(lll) for lll in ll.split('+')])
                if tmp > l_out:
                    l_out = tmp
        if c.strip() == "":
            c = 0
        else:
            if l_out <= 6:
                c = 0
            else:
                c = 1
        dataset_dict[s] = {"age":a,"psa":p,"volume":v,"gs":l_out,"label":c}

    return dataset_dict

clinical_data = retrieve_clinical_data(clinical_info_path)
        
pd.DataFrame.from_dict(clinical_data)
# Out:
#        1000000 1000001 1000002 1000003 1000004 1000005 1000006 1000007  \
# age         74      64      58      72      67      64      73      68
# psa        7.7     8.7     4.2      13       8    12.1     6.2    3.83
# volume      55     102      74    71.5      78      51      27      41
# gs           0       0       0       0       0       7       6       6
# label        0       0       0       0       0       1       0       0
#
#        1000008 1000009  ... 1001490 1001491 1001492 1001493 1001494 1001495  \
# age         81      68  ...      77      61      64      49      62      71
# psa       11.1      24  ...      11     5.4     4.3     4.3     9.1    12.5
# volume      56     120  ...      65     103      23      34      47      62
# gs           7       0  ...       0       6       7       0       0       7
# label        1       0  ...       0       0       1       0       0       1
#
#        1001496 1001497 1001498 1001499
# age         81      56      75      56
# psa       5.28    29.6      12      15
# volume      44      87      83      33
# gs           7       0       6       9
# label        1       0       0       1
#
# [5 rows x 1500 columns]

# %%
class StrToOneHot:
    def __init__(self,sl:list[str]):
        self.sl = sorted(sl)
        self.match = {k:i for i,k in enumerate(self.sl)}
        self.n = len(sl)

    def __call__(self,X:str):
        output = np.zeros([self.n])
        output[self.match[X]] = 1
        return torch.Tensor(output)

class TabularData(monai.data.Dataset):
    def __init__(self,data_dict:dict,
                 data_types:dict=None)->monai.data.Dataset:
        self.data_dict = data_dict
        self.data_types = data_types
        self.keys = list(data_dict.keys())

        if self.data_types is None:
            self.data_types = {
                k:"numerical" for k in self.data_dict[self.keys[0]]}
        self.setup_transforms()

    def setup_transforms(self):
        self.transforms = {}
        for k in self.data_types:
            if self.data_types[k] == "categorical":
                all_options = [self.data_dict[kk][k] for kk in self.data_dict]
                all_options = list(set(all_options))
                all_options = [x for x in all_options if x != ""]
                self.transforms[k] = StrToOneHot(all_options)
            else:
                self.transforms[k] = self.to_float
    
    def remove_incomplete_keys(self):
        o = []
        for i in self.keys:
            try:
                self[i]
                o.append(i)
            except:
                pass
        self.keys = o

    def to_float(self,X):
        return torch.Tensor([float(X)])
    
    def __len__(self):
        return len(self.data_dict)
        
    def __getitem__(self,i):
        if isinstance(i,int):
            i = self.keys[i]

        return {
            k:self.transforms[k](self.data_dict[i][k])
            for k in self.transforms}

clinical_dataset = TabularData(
    clinical_data,
    {'age':'numerical','psa':'numerical',
    'volume':'numerical','gs':'categorical','label':'numerical'})

clinical_dataset.remove_incomplete_keys()

import time
times = []
for i in clinical_dataset.keys:
    a = time.time()
    clinical_dataset[i]
    b = time.time()
    times.append(b-a)

# %% [markdown]
# ## Using MONAIDataset to create an MRI scan dataset

# %%
all_files = sorted(glob("/home/jose_almeida/data/PI-CAI/dataset/*/*/*mha"))

path_dictionary = {}
reader = sitk.ImageFileReader()
modalities = ['adc','hbv','t2w']
metadata_dictionary = {"shape":{k:[] for k in modalities},
                       "spacing":{k:[] for k in modalities}}
for f in all_files:
    study_id = f.split('_')[-2]
    mod = f.split('_')[-1].split('.')[0]
    if mod in modalities:
        if study_id in path_dictionary:
            path_dictionary[study_id][mod] = f
        else:
            path_dictionary[study_id] = {mod:f}
    
    reader.SetFileName(f)
    reader.LoadPrivateTagsOn()
    reader.ReadImageInformation()
    sh = reader.GetSize()
    sp = reader.GetSpacing()
    
    if mod in modalities:
        metadata_dictionary['shape'][mod].append(sh)
        metadata_dictionary['spacing'][mod].append(sp)

# %%
shape_dict = {
    k:tuple(np.int32(np.median(np.array(metadata_dictionary['shape'][k]),axis=0)))
    for k in modalities}

spacing_dict = {
    k:tuple(np.int32(np.median(np.array(metadata_dictionary['spacing'][k]),axis=0)))
    for k in modalities}

transforms = []
for k in modalities:
    transforms.extend(
        [monai.transforms.Spacingd([k],tuple(spacing_dict["t2w"])),
         monai.transforms.Resized([k],tuple(shape_dict["t2w"]))])

# %%
dataset = MONAIDataset(
    path_dictionary,data_type="mha",padding=False,orientation="RAS",
    image_keys=modalities,transforms=transforms)

# %%
for d in dataset:
    print({k:d[k].shape for k in modalities})
# Out:
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# {'adc': torch.Size([1, 384, 384, 21]), 'hbv': torch.Size([1, 384, 384, 21]), 't2w': torch.Size([1, 384, 384, 21])}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb Cell 10' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000018vscode-remote?line=0'>1</a> for d in dataset:
#       <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000018vscode-remote?line=1'>2</a>     print({k:d[k].shape for k in modalities})
#
# File ~/projects/pi-cai/lib/dataoperations/lib/data_functions.py:514, in MONAIDataset.__getitem__(self, index)
#     <a href='file:///home/jose_almeida/projects/pi-cai/lib/dataoperations/lib/data_functions.py?line=511'>512</a>     X[im_k] = torch.Tensor(X[im_k])
#     <a href='file:///home/jose_almeida/projects/pi-cai/lib/dataoperations/lib/data_functions.py?line=512'>513</a> if self.transform_ops is not None:
# --> <a href='file:///home/jose_almeida/projects/pi-cai/lib/dataoperations/lib/data_functions.py?line=513'>514</a>     X = self.transform_ops(X)
#     <a href='file:///home/jose_almeida/projects/pi-cai/lib/dataoperations/lib/data_functions.py?line=514'>515</a> output_dict = {k:X[k] for k in self.image_keys}
#     <a href='file:///home/jose_almeida/projects/pi-cai/lib/dataoperations/lib/data_functions.py?line=515'>516</a> return output_dict
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/compose.py:173, in Compose.__call__(self, input_)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/compose.py?line=170'>171</a> def __call__(self, input_):
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/compose.py?line=171'>172</a>     for _transform in self.transforms:
# --> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/compose.py?line=172'>173</a>         input_ = apply_transform(_transform, input_, self.map_items, self.unpack_items, self.log_stats)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/compose.py?line=173'>174</a>     return input_
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py:89, in apply_transform(transform, data, map_items, unpack_items, log_stats)
#      <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=86'>87</a>     if isinstance(data, (list, tuple)) and map_items:
#      <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=87'>88</a>         return [_apply_transform(transform, item, unpack_items) for item in data]
# ---> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=88'>89</a>     return _apply_transform(transform, data, unpack_items)
#      <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=89'>90</a> except Exception as e:
#      <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=91'>92</a>     if log_stats and not isinstance(transform, transforms.compose.Compose):
#      <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=92'>93</a>         # log the input data information of exact transform in the transform chain
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py:53, in _apply_transform(transform, parameters, unpack_parameters)
#      <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=49'>50</a> if isinstance(parameters, tuple) and unpack_parameters:
#      <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=50'>51</a>     return transform(*parameters)
# ---> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=52'>53</a> return transform(parameters)
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py:243, in Spacingd.__call__(self, data)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=239'>240</a> # resample array of each corresponding key
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=240'>241</a> # using affine fetched from d[affine_key]
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=241'>242</a> original_spatial_shape = d[key].shape[1:]
# --> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=242'>243</a> d[key], old_affine, new_affine = self.spacing_transform(
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=243'>244</a>     data_array=d[key],
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=244'>245</a>     affine=meta_data["affine"],
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=245'>246</a>     mode=mode,
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=246'>247</a>     padding_mode=padding_mode,
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=247'>248</a>     align_corners=align_corners,
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=248'>249</a>     dtype=dtype,
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=249'>250</a> )
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=250'>251</a> self.push_transform(
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=251'>252</a>     d,
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=252'>253</a>     key,
#    (...)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=260'>261</a>     orig_size=original_spatial_shape,
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=261'>262</a> )
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/dictionary.py?line=262'>263</a> # set the 'affine' key
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/array.py:220, in Spacing.__call__(self, data_array, affine, mode, padding_mode, align_corners, dtype, output_spatial_shape)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/array.py?line=217'>218</a>     data_array_t: torch.Tensor
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/array.py?line=218'>219</a>     data_array_t, *_ = convert_data_type(data_array, torch.Tensor, dtype=_dtype)  # type: ignore
# --> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/array.py?line=219'>220</a>     output_data = affine_xform(
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/array.py?line=220'>221</a>         # AffineTransform requires a batch dim
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/array.py?line=221'>222</a>         data_array_t.unsqueeze(0),
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/array.py?line=222'>223</a>         convert_data_type(transform, torch.Tensor, data_array_t.device, dtype=_dtype)[0],
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/array.py?line=223'>224</a>         spatial_size=output_shape if output_spatial_shape is None else output_spatial_shape,
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/array.py?line=224'>225</a>     ).squeeze(0)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/array.py?line=226'>227</a> output_data, *_ = convert_to_dst_type(output_data, data_array, dtype=torch.float32)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/spatial/array.py?line=227'>228</a> new_affine = to_affine_nd(affine_np, new_affine)  # type: ignore
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1105'>1106</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1106'>1107</a> # this function, and just call forward.
#    <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1107'>1108</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1108'>1109</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1109'>1110</a>     return forward_call(*input, **kwargs)
#    <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1110'>1111</a> # Do not call functions when jit is used
#    <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/modules/module.py?line=1111'>1112</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/monai/networks/layers/spatial_transforms.py:543, in AffineTransform.forward(self, src, theta, spatial_size)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/networks/layers/spatial_transforms.py?line=537'>538</a>     raise ValueError(
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/networks/layers/spatial_transforms.py?line=538'>539</a>         f"affine and image batch dimension must match, got affine={theta.shape[0]} image={src_size[0]}."
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/networks/layers/spatial_transforms.py?line=539'>540</a>     )
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/networks/layers/spatial_transforms.py?line=541'>542</a> grid = nn.functional.affine_grid(theta=theta[:, :sr], size=list(dst_size), align_corners=self.align_corners)
# --> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/networks/layers/spatial_transforms.py?line=542'>543</a> dst = nn.functional.grid_sample(
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/networks/layers/spatial_transforms.py?line=543'>544</a>     input=src.contiguous(),
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/networks/layers/spatial_transforms.py?line=544'>545</a>     grid=grid,
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/networks/layers/spatial_transforms.py?line=545'>546</a>     mode=self.mode.value,
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/networks/layers/spatial_transforms.py?line=546'>547</a>     padding_mode=self.padding_mode.value,
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/networks/layers/spatial_transforms.py?line=547'>548</a>     align_corners=self.align_corners,
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/networks/layers/spatial_transforms.py?line=548'>549</a> )
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/networks/layers/spatial_transforms.py?line=549'>550</a> return dst
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/functional.py:4201, in grid_sample(input, grid, mode, padding_mode, align_corners)
#    <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/functional.py?line=4192'>4193</a>     warnings.warn(
#    <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/functional.py?line=4193'>4194</a>         "Default grid_sample and affine_grid behavior has changed "
#    <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/functional.py?line=4194'>4195</a>         "to align_corners=False since 1.3.0. Please specify "
#    <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/functional.py?line=4195'>4196</a>         "align_corners=True if the old behavior is desired. "
#    <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/functional.py?line=4196'>4197</a>         "See the documentation of grid_sample for details."
#    <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/functional.py?line=4197'>4198</a>     )
#    <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/functional.py?line=4198'>4199</a>     align_corners = False
# -> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/torch/nn/functional.py?line=4200'>4201</a> return torch.grid_sampler(input, grid, mode_enum, padding_mode_enum, align_corners)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Using MONAIDataset to create a segmentation map dataset

# %%
labels_path = "/home/jose_almeida/data/PI-CAI/labels/csPCa_lesion_delineations/human_expert/resampled/*"
all_label_paths = glob(os.path.join(labels_path,"*"))
labels_path_original = "/home/jose_almeida/data/PI-CAI/labels/csPCa_lesion_delineations/human_expert/original/*"
all_label_paths_original = glob(os.path.join(labels_path_original,"*"))

path_dictionary_labels = {}
for label_path in all_label_paths_original:
    study_id = label_path.split('_')[-1].split('.')[0]
    path_dictionary_labels[study_id] = {"segmentation_labels":label_path}

segmentation_map_dataset = MONAIDataset(
    path_dictionary_labels,data_type="nifti",padding=False,
    orientation="RAS",image_keys=["segmentation_labels"])

# %% [markdown]
# ## The MultiDataset class

# %%
class MultiDataset(monai.data.Dataset):
    def __init__(self,
                 *datasets:List[monai.data.Dataset],
                 data_keys:list,
                 transforms:monai.transforms.Transform=None):
        self.datasets = datasets
        self.data_keys = data_keys
        self.transforms = transforms

        self.get_common_keys()

    def get_common_keys(self):
        self.keys = []
        all_keys = {}
        for dataset in self.datasets:
            for k in dataset.keys:
                if k not in all_keys:
                    all_keys[k] = 1
                else:
                    all_keys[k] += 1
        for k in all_keys:
            if all_keys[k] == len(self.datasets):
                self.keys.append(k)

    def __len__(self):
        return len(self.keys)
        
    def __getitem__(self,i):
        if isinstance(i,int):
            i = self.keys[i]

        output = {}
        for dataset in self.datasets:
            output.update(
                {k:dataset[i][k] for k in dataset[i]
                 if k in self.data_keys})
        
        if self.transforms is not None:
            output = self.transforms(output)
            
        return output
        
comb_dataset = MultiDataset(
    dataset,clinical_dataset,segmentation_map_dataset,
    data_keys=["adc","hbv","t2w","segmentation_labels","gs","volume","psa"])

comb_dataloader = torch.utils.data.DataLoader(
    comb_dataset,num_workers=4,batch_size=2,prefetch_factor=10)

print("Number of common keys:",len(comb_dataset.keys))
"""
for i in range(len(comb_dataset)):
    dat = comb_dataset[i]
    print({k:dat[k].shape for k in dat})
"""
for element in tqdm(comb_dataloader):
    pass
# Out:
# Number of common keys: 1237
# {'adc': torch.Size([1, 116, 114, 31])}
# {'adc': torch.Size([1, 120, 128, 21])}
# {'adc': torch.Size([1, 120, 128, 22])}
# {'adc': torch.Size([1, 120, 128, 23])}
# {'adc': torch.Size([1, 120, 128, 21])}
# {'adc': torch.Size([1, 84, 128, 19])}
# {'adc': torch.Size([1, 120, 128, 21])}
# {'adc': torch.Size([1, 120, 128, 19])}
# {'adc': torch.Size([1, 256, 256, 27])}
# {'adc': torch.Size([1, 120, 128, 19])}
# {'adc': torch.Size([1, 224, 224, 16])}
# {'adc': torch.Size([1, 84, 128, 19])}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb Cell 10' in <cell line: 45>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=42'>43</a> print("Number of common keys:",len(comb_dataset.keys))
#      <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=44'>45</a> for i in range(len(comb_dataset)):
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=45'>46</a>     dat = comb_dataset[i]
#      <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=46'>47</a>     print({k:dat[k].shape for k in dat})
#      <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=48'>49</a> for element in tqdm(comb_dataloader):
#
# /home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb Cell 10' in CombinationDataset.__getitem__(self, i)
#      <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=27'>28</a> output = {}
#      <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=28'>29</a> for dataset in self.datasets:
#      <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=29'>30</a>     output.update(
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=30'>31</a>         {k:dataset[i][k] for k in dataset[i]
#      <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=31'>32</a>          if k in self.data_keys})
#      <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=33'>34</a> return output
#
# /home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb Cell 10' in <dictcomp>(.0)
#      <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=27'>28</a> output = {}
#      <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=28'>29</a> for dataset in self.datasets:
#      <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=29'>30</a>     output.update(
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=30'>31</a>         {k:dataset[i][k] for k in dataset[i]
#      <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=31'>32</a>          if k in self.data_keys})
#      <a href='vscode-notebook-cell://ssh-remote%2Bccig-ml3/home/jose_almeida/projects/pi-cai/data-loading-pi-cai.ipynb#ch0000009vscode-remote?line=33'>34</a> return output
#
# File ~/projects/pi-cai/lib/dataoperations/lib/data_functions.py:510, in MONAIDataset.__getitem__(self, index)
#     <a href='file:///home/jose_almeida/projects/pi-cai/lib/dataoperations/lib/data_functions.py?line=506'>507</a>     k = self.keys[index]
#     <a href='file:///home/jose_almeida/projects/pi-cai/lib/dataoperations/lib/data_functions.py?line=508'>509</a> path_dict = {kk:self.path_dictionary[k][kk] for kk in self.image_keys}
# --> <a href='file:///home/jose_almeida/projects/pi-cai/lib/dataoperations/lib/data_functions.py?line=509'>510</a> X = self.image_loader(path_dict)
#     <a href='file:///home/jose_almeida/projects/pi-cai/lib/dataoperations/lib/data_functions.py?line=510'>511</a> for im_k in self.image_keys:
#     <a href='file:///home/jose_almeida/projects/pi-cai/lib/dataoperations/lib/data_functions.py?line=511'>512</a>     X[im_k] = torch.Tensor(X[im_k])
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/compose.py:173, in Compose.__call__(self, input_)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/compose.py?line=170'>171</a> def __call__(self, input_):
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/compose.py?line=171'>172</a>     for _transform in self.transforms:
# --> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/compose.py?line=172'>173</a>         input_ = apply_transform(_transform, input_, self.map_items, self.unpack_items, self.log_stats)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/compose.py?line=173'>174</a>     return input_
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py:89, in apply_transform(transform, data, map_items, unpack_items, log_stats)
#      <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=86'>87</a>     if isinstance(data, (list, tuple)) and map_items:
#      <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=87'>88</a>         return [_apply_transform(transform, item, unpack_items) for item in data]
# ---> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=88'>89</a>     return _apply_transform(transform, data, unpack_items)
#      <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=89'>90</a> except Exception as e:
#      <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=91'>92</a>     if log_stats and not isinstance(transform, transforms.compose.Compose):
#      <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=92'>93</a>         # log the input data information of exact transform in the transform chain
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py:53, in _apply_transform(transform, parameters, unpack_parameters)
#      <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=49'>50</a> if isinstance(parameters, tuple) and unpack_parameters:
#      <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=50'>51</a>     return transform(*parameters)
# ---> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/transform.py?line=52'>53</a> return transform(parameters)
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/io/dictionary.py:121, in LoadImaged.__call__(self, data, reader)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/io/dictionary.py?line=118'>119</a> d = dict(data)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/io/dictionary.py?line=119'>120</a> for key, meta_key, meta_key_postfix in self.key_iterator(d, self.meta_keys, self.meta_key_postfix):
# --> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/io/dictionary.py?line=120'>121</a>     data = self._loader(d[key], reader)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/io/dictionary.py?line=121'>122</a>     if self._loader.image_only:
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/io/dictionary.py?line=122'>123</a>         if not isinstance(data, np.ndarray):
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/io/array.py:194, in LoadImage.__call__(self, filename, reader)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/io/array.py?line=191'>192</a> if self.auto_select:  # rely on the filename extension to choose the reader
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/io/array.py?line=192'>193</a>     if reader.verify_suffix(filename):
# --> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/io/array.py?line=193'>194</a>         img = reader.read(filename)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/io/array.py?line=194'>195</a>         break
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/transforms/io/array.py?line=195'>196</a> else:  # try the user designated readers
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/monai/data/image_reader.py:244, in ITKReader.read(self, data, **kwargs)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/data/image_reader.py?line=241'>242</a>         img_.append(_obj)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/data/image_reader.py?line=242'>243</a>     else:
# --> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/data/image_reader.py?line=243'>244</a>         img_.append(itk.imread(name, **kwargs_))
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/monai/data/image_reader.py?line=244'>245</a> return img_ if len(filenames) > 1 else img_[0]
#
# File ~/miniconda3/envs/mri/lib/python3.9/site-packages/itk/support/extras.py:966, in imread(filename, pixel_type, fallback_only, imageio)
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/itk/support/extras.py?line=963'>964</a> else:
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/itk/support/extras.py?line=964'>965</a>     reader = template_reader_type.New(**kwargs)
# --> <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/itk/support/extras.py?line=965'>966</a> reader.Update()
#     <a href='file:///home/jose_almeida/miniconda3/envs/mri/lib/python3.9/site-packages/itk/support/extras.py?line=966'>967</a> return reader.GetOutput()
#
# KeyboardInterrupt:
